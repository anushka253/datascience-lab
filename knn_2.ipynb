# %%
#1
#knn
#using data set
#iris

# %%
from sklearn import datasets
from sklearn import neighbors
from sklearn.model_selection import train_test_split


df=datasets.load_iris()
x=df.data
y=df.target




x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)


c=neighbors.KNeighborsClassifier(n_neighbors=3)


c.fit(x_train,y_train)

print(c.score(x_test,y_test))

feature = [[int(i) for i in input("sl,sw,pl,pw:").split()]]

r=c.predict(feature)
print(r)#reeturns index
print(df['target_names'][r])#a indexile target name
# Out:
# 0.9555555555555556
# [0]
# ['setosa']

# %%
#to find accuracy
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets

d=datasets.load_iris()
x=df.data
y=df.target

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)


c=neighbors.KNeighborsClassifier(n_neighbors=3)


c.fit(x_train,y_train)
print(c.score(x_test,y_test))

r=c.predict(x_test)
print(accuracy_score(r,y_test)*100)
# Out:
# 0.9777777777777777
# 97.77777777777777

# %%
#using csv import
#check diab or not

# %%
from sklearn import neighbors
import pandas as pd

df=pd.read_csv("diab.csv")
x=[["BMI","Age"]]#eeeeeeerrroooooooorrrrrrrrrrrrr!!!!
y=["Sugar"]

c=neighbors.KNeighborsClassifier(n_neighbors=3)
c.fit(x,y)

f=[[int(i) for i in input("enter 2 ").split()]]

r=c.predict(f)

if r==0:
    print("d")
else:
    print("N")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\OneDrive\Desktop\s3\ds lab\knn_2.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Desktop/s3/ds%20lab/knn_2.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> y=["Sugar"]
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Desktop/s3/ds%20lab/knn_2.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> c=neighbors.KNeighborsClassifier(n_neighbors=3)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Desktop/s3/ds%20lab/knn_2.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> c.fit(x,y)
#      <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Desktop/s3/ds%20lab/knn_2.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> f=[[int(i) for i in input("enter 2 ").split()]]
#      <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Desktop/s3/ds%20lab/knn_2.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> r=c.predict(f)
#
# ...

# %%
from sklearn import neighbors
import pandas as pd
import numpy as np

df=pd.read_csv("diabs.csv")
x=df[["BMI","Age"]]
y=df["Sugar"]

c=neighbors.KNeighborsClassifier(n_neighbors=3)
c.fit(x,y)

f =[[int(i) for i in input("enter 2 ").split()]]

r=c.predict(f)

if r==0:
    print("d")
else:
    print("N")
# Out:
# N
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn import neighbors
import pandas as pd

df=pd.read_csv("diabs.csv")
x=df[["BMI","Age"]]#df!
y=df["Sugar"]

c=neighbors.KNeighborsClassifier(n_neighbors=3)
c.fit(x,y)
print(c.score(x,y))
z=c.predict(x)
print("hjh")
print(accuracy_score(z,y)*100)


f=[[int(i) for i in input("enter 2 ").split()]]

r=c.predict(f)

if r==0:
    print("d")
else:
    print("N")
# Out:
# 0.8
# hjh
# 80.0
# N
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd

df=pd.read_csv('diabs.csv')
x=df[['BMI','Age']]
y=df['Sugar']

x_test,x_train,y_test,y_train=train_test_split(x,y,train_size=0.7)

c=neighbors.KNeighborsClassifier(n_neighbors=3)

c.fit(x_train,y_train)
print(c.score(x_train,y_train))

r=c.predict(x_test)
print(accuracy_score(r,y_test))
# Out:
# 0.6666666666666666
# 0.42857142857142855

# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')
df.plot.scatter('Age','BMI',c="Outcome",colormap="viridis")

df.plot.bar('Age',"BMI")

plt.show()
# This will create a scatter plot with Age on the x-axis and BMI on the y-axis.
# The color of each point is determined by the value of Outcome
# viridis is a colormap in matplotlib that is designed to be perceptually uniform and colorblind-friendly. 
# It is a good choice for visualizing data that varies smoothly over a range of values. 
# The colormap ranges from blue to yellow, with a gradual transition through green.
#plot used with dataframe
#matplotlib not used

# %%
from sklearn import datasets
from sklearn import neighbors
from sklearn.model_selection import train_test_split


df=datasets.load_iris()
x=df.data
y=df.target




x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)


c=neighbors.KNeighborsClassifier(n_neighbors=3)


c.fit(x_train,y_train)

print(c.score(x_test,y_test))

feature = [[int(i) for i in input("sl,sw,pl,pw:").split()]]

r=c.predict(feature)
print(r)#reeturns index
print(df['target_names'][r])#a indexile target name
# Out:
# 0.9333333333333333
# [0]
# ['setosa']
